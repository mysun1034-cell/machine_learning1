# %% [markdown]
# ## YOLO
#
# You Only Look Once!!!

# %% [markdown]
# ## 객체탐지

# %%
# !pip install matplotlib plotly
# Out:
# Requirement already satisfied: matplotlib in c:\users\kim\appdata\local\programs\python\python311\lib\site-packages (3.10.9)
# Requirement already satisfied: plotly in c:\users\kim\appdata\local\programs\python\python311\lib\site-packages (6.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\kim\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\kim\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kim\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\kim\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in c:\users\kim\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (2.4.6)
# Requirement already satisfied: packaging>=20.0 in c:\users\kim\appdata\roaming\python\python311\site-packages (from matplotlib) (26.2)
# Requirement already satisfied: pillow>=8 in c:\users\kim\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\kim\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kim\appdata\roaming\python\python311\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\kim\appdata\local\programs\python\python311\lib\site-packages (from plotly) (2.22.0)
# Requirement already satisfied: six>=1.5 in c:\users\kim\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# [notice] A new release of pip is available: 24.0 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install ultralytics
# Out:
# Requirement already satisfied: ultralytics in c:\users\kim\appdata\local\programs\python\python311\lib\site-packages (8.4.62)
# Requirement already satisfied: numpy>=1.23.0 in c:\users\kim\appdata\local\programs\python\python311\lib\site-packages (from ultralytics) (2.4.6)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\kim\appdata\local\programs\python\python311\lib\site-packages (from ultralytics) (3.10.9)
# Requirement already satisfied: opencv-python>=4.6.0 in c:\users\kim\appdata\local\programs\python\python311\lib\site-packages (from ultralytics) (4.13.0.92)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\kim\appdata\local\programs\python\python311\lib\site-packages (from ultralytics) (12.2.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\kim\appdata\local\programs\python\python311\lib\site-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in c:\users\kim\appdata\local\programs\python\python311\lib\site-packages (from ultralytics) (2.34.2)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\kim\appdata\local\programs\python\python311\lib\site-packages (from ultralytics) (1.17.1)
# Requirement already satisfied: torch>=1.8.0 in c:\users\kim\appdata\local\programs\python\python311\lib\site-packages (from ultralytics) (2.12.0)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\kim\appdata\local\programs\python\python311\lib\site-packages (from ultralytics) (0.27.0)
# Requirement already satisfied: psutil>=5.8.0 in c:\users\kim\appdata\roaming\python\python311\site-packages (from ultralytics) (7.2.2)
# Requirement already satisfied: polars>=0.20.0 in c:\users\kim\appdata\local\programs\python\python311\lib\site-packages (from ultralytics) (1.41.2)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in c:\users\kim\appdata\local\programs\python\python311\lib\site-packages (from ultralytics) (2.0.20)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\kim\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\kim\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kim\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\kim\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\kim\appdata\roaming\python\python311\site-packages (from matplotlib>=3.3.0->ultralytics) (26.2)
# Requirement already satisfied: pyparsing>=3 in c:\users\kim\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kim\appdata\roaming\python\python311\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: polars-runtime-32==1.41.2 in c:\users\kim\appdata\local\programs\python\python311\lib\site-packages (from polars>=0.20.0->ultralytics) (1.41.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\kim\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.23.0->ultralytics) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kim\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.23.0->ultralytics) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\kim\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.23.0->ultralytics) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\kim\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.23.0->ultralytics) (2026.5.20)
# Requirement already satisfied: filelock in c:\users\kim\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.8.0->ultralytics) (3.29.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\kim\appdata\roaming\python\python311\site-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools<82 in c:\users\kim\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.8.0->ultralytics) (65.5.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\kim\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\kim\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.8.0->ultralytics) (3.6.1)
# Requirement already satisfied: jinja2 in c:\users\kim\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\kim\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.8.0->ultralytics) (2026.4.0)
# Requirement already satisfied: six>=1.5 in c:\users\kim\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\kim\appdata\local\programs\python\python311\lib\site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\kim\appdata\local\programs\python\python311\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# [notice] A new release of pip is available: 24.0 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from PIL import Image
from ultralytics import YOLO
import matplotlib.pyplot as plt

# %%
img = Image.open("dog.jpg")
plt.imshow(img)
results = model.predict("dog.jpg")
# Out:
# image 1/1 c:\Users\kim\Desktop\p1-data\c3_deep_learning\dog.jpg: 640x640 1 dog, 1 chair, 57.3ms
# Speed: 3.5ms preprocess, 57.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)

# %%
model = YOLO("yolo11n.pt")

# %%
model(img)
# Out:
# 0: 640x640 1 dog, 1 chair, 72.4ms
# Speed: 16.4ms preprocess, 72.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
#  obb: None
#  orig_img: array([[[102, 110, 109],
#          [102, 110, 109],
#          [101, 109, 108],
#          ...,
#          [ 60,  68,  58],
#          [ 63,  71,  61],
#          [ 65,  73,  63]],
#
#         [[101, 109, 108],
#          [101, 109, 108],
#          [100, 108, 107],
#          ...,
#          [ 59,  67,  57],
#          [ 61,  69,  59],
#          [ 63,  71,  61]],
#
#         [[ 99, 107, 106],
#          [ 99, 107, 106],
#          [ 98, 106, 105],
#          ...,
#          [ 57,  65,  55],
#          [ 59,  67,  57],
#          [ 61,  69,  59]],
#
#         ...,
#
#         [[130, 132, 120],
#          [126, 128, 116],
#          [121, 123, 111],
#          ...,
#          [104, 116, 120],
#          [ 96, 108, 112],
#          [ 90, 102, 106]],
#
#         [[133, 135, 123],
#          [128, 130, 118],
#          [124, 126, 114],
#          ...,
#          [103, 115, 119],
#          [ 97, 109, 113],
#          [ 93, 105, 109]],
#
#         [[134, 136, 124],
#          [130, 132, 120],
#          [125, 127, 115],
#          ...,
#          [101, 113, 117],
#          [ 97, 109, 113],
#          [ 96, 108, 112]]], shape=(2048, 2048, 3), dtype=uint8)
#  orig_shape: (2048, 2048)
#  path: 'dog.jpg'
#  probs: None
#  save_dir: 'C:\\Users\\kim\\Desktop\\p1-data\\c3_deep_learning\\runs\\detect\\predict'
#  semantic_mask: None
#  speed: {'preprocess': 16.441800000393414, 'inference': 72.35779999973602, 'postprocess': 1.149900001109927}]

# %%
import cv2

# %%
# 4. 결과 시각화 및 화면 표시 
for result in results: 
    # 탐지된 객체의 바운딩 박스가 그려진 이미지 가져오기 
    annotated_frame = result.plot() 
    # # 결과 화면에 출력 
    cv2.imshow("YOLO Detection Result", annotated_frame) 
    cv2.waitKey(0) 

cv2.destroyAllWindows()
